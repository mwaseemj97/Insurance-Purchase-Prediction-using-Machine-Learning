# %%
import pandas as pd 
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker = '+', color = 'red')
plt.savefig('image1')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size = 0.25, random_state = 40)

# %%
len(X_train)
# Out:
# 20

# %%
len(X_test)
# Out:
# 7

# %%
from sklearn.linear_model import LogisticRegression

# %%
X = df['age']
y = df['bought_insurance']

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 0, 0, 1, 1, 0, 0])

# %%
X_test
# Out:
#     age
# 2    47
# 16   25
# 19   18
# 14   49
# 15   55
# 13   29
# 20   21

# %%
model.score(X_test, y_test)
# Out:
# 0.8571428571428571

# %%
model.predict_proba(X_test)
# Out:
# array([[0.33722674, 0.66277326],
#        [0.93474199, 0.06525801],
#        [0.97642901, 0.02357099],
#        [0.27307128, 0.72692872],
#        [0.13131861, 0.86868139],
#        [0.88646048, 0.11353952],
#        [0.96334134, 0.03665866]])

# %%
X_new = pd.DataFrame([[56]], columns = ['age'])

model.predict(X_new)
# Out:
# array([1])
